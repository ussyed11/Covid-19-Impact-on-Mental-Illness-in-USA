# %% [markdown]
# <a href="https://colab.research.google.com/github/ussyed11/Covid-19-Impact-on-Mental-Depression-in-USA/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a0972281-dcbe-442e-b8a1-c19c4ab92424" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0972281-dcbe-442e-b8a1-c19c4ab92424">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv to United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv']))
df.head()
# Out:
#   submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      01/14/2022    KS     621273    470516.0    150757.0     19414
# 1      01/02/2022    AS         11         NaN         NaN         0
# 2      05/30/2022    AK     251425         NaN         NaN         0
# 3      07/23/2020    TX     361125         NaN         NaN      9507
# 4      08/12/2020    AS          0         NaN         NaN         0
#
#    pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0     6964.0       7162         NaN         NaN         21         4.0
# 1        0.0          0         NaN         NaN          0         0.0
# 2        0.0       1252         NaN         NaN          0         0.0
# 3        0.0       7981         NaN         NaN        281         0.0
# 4        0.0          0         NaN         NaN          0         0.0
#
#                created_at consent_cases consent_deaths
# 0  01/15/2022 02:59:30 PM         Agree            NaN
# ...

# %%
df = df.dropna(subset=['tot_cases'])

df.head()
# Out:
#   submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      01/14/2022    KS     621273    470516.0    150757.0     19414
# 1      01/02/2022    AS         11         NaN         NaN         0
# 2      05/30/2022    AK     251425         NaN         NaN         0
# 3      07/23/2020    TX     361125         NaN         NaN      9507
# 4      08/12/2020    AS          0         NaN         NaN         0
#
#    pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0     6964.0       7162         NaN         NaN         21         4.0
# 1        0.0          0         NaN         NaN          0         0.0
# 2        0.0       1252         NaN         NaN          0         0.0
# 3        0.0       7981         NaN         NaN        281         0.0
# 4        0.0          0         NaN         NaN          0         0.0
#
#                created_at consent_cases consent_deaths
# 0  01/15/2022 02:59:30 PM         Agree            NaN
# ...

# %%
df.columns
# Out:
# Index(['submission_date', 'state', 'tot_cases', 'conf_cases', 'prob_cases',
#        'new_case', 'pnew_case', 'tot_death', 'conf_death', 'prob_death',
#        'new_death', 'pnew_death', 'created_at', 'consent_cases',
#        'consent_deaths'],
#       dtype='object')

# %%
df = df.groupby(['state']).sum(['tot_case'])
df.head()
# Out:
#        tot_cases   conf_cases   prob_cases  new_case  pnew_case  tot_death  \
# state
# AK      76993509          0.0          0.0    263307        0.0     406984
# AL     495866086  372514245.0  123351841.0   1370792   388554.0    8946436
# AR     314253729          0.0          0.0    871467   247126.0    4678130
# AS        618133          0.0          0.0      6505        0.0       2546
# AZ     762685906  691776565.0   70849280.0   2145765   256800.0   12984264
#
#        conf_death  prob_death  new_death  pnew_death
# state
# AK            0.0         0.0       1109         0.0
# AL      7052062.0   1894374.0      19781      4602.0
# AR            0.0         0.0      11316      2830.0
# AS            0.0         0.0         31         0.0
# AZ     11445303.0   1537111.0      30810      3994.0

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    state   tot_cases    conf_cases   prob_cases  new_case  pnew_case  \
# 0     AK    76993509  0.000000e+00          0.0    263307        0.0
# 1     AL   495866086  3.725142e+08  123351841.0   1370792   388554.0
# 2     AR   314253729  0.000000e+00          0.0    871467   247126.0
# 3     AS      618133  0.000000e+00          0.0      6505        0.0
# 4     AZ   762685906  6.917766e+08   70849280.0   2145765   256800.0
# 5     CA  3305642241  3.159478e+09  146164163.0  10035241   534865.0
# 6     CO   499355370  4.589697e+08   40385635.0   1546422   142342.0
# 7     CT   282636713  2.564638e+08   25991615.0    819915    87368.0
# 8     DC    48506690  0.000000e+00          0.0    157435        0.0
# 9     DE    94405711  8.714778e+07    7257933.0    286412    25893.0
# 10    FL  2202577503  0.000000e+00          0.0   6547636  1449855.0
# 11   FSM        4088  4.088000e+03          0.0        31        0.0
# 12    GA   982508875  7.782181e+08  204290780.0   2656707   601276.0
# ...

# %%
plt.scatter(df.state, df.tot_cases)
plt.xlabel('States')
plt.ylabel('Total Cases')
plt.show()

# %%
X = df.tot_cases.values.reshape(-1, 1)

# %%
X.shape
# Out:
# (60, 1)

# %%
y = df.state

# %%
model = LinearRegression()
